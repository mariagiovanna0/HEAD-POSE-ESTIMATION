# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Scrip per effettuare un analisi delle immagini del dataset BIWI scartate in fase di face detection ed extraction.

# %%
import os

def rejected_counter(path_folder):
    tot=0
    for folder in os.listdir(path_folder):
        c=0
        for item in os.listdir(os.path.join(path_folder,folder)):
            c+=1
        tot+=c
        print("Rejected in folder "+path_folder+folder+": ", c)
    print("Rejected in all dataset: ",tot)


if __name__ == '__main__':
    path_rejected_folder="/content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/"
    rejected_counter(path_rejected_folder)
# Out:
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/1:  0
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/2:  19
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/3:  0
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/4:  1
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/5:  0
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/6:  50
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/7:  5
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/8:  0
# Rejected in folder /content/drive/Shareddrives/Progetto/Colab Notebooks/Volti non identificati/9:  46
# ...
